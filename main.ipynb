# %%
# auto-reload all helper files
# %load_ext autoreload
# %autoreload 2

# %%
# Imports
import config
import numpy as np
from data import get_cifar10_data
from model import build_model
from train import compile_model, train_model, evaluate_model
from metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
x_train, y_train, x_test, y_test = get_cifar10_data()

# %%
# Build and compile - # Run ONCE per model lifecycle as it resets model weights

model = build_model()
model = compile_model(model)

# %%
# Train model

history = train_model(
    model,
    x_train,
    y_train,
    batch_size=config.BATCH_SIZE,
    epochs=config.EPOCHS,
)

print(">>> TRAINING STARTING <<<")
# Out:
# Epoch 1/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 60s 81ms/step - accuracy: 0.3164 - loss: 1.8982 - val_accuracy: 0.4370 - val_loss: 1.6427 - learning_rate: 3.0000e-04
# Epoch 2/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 57s 81ms/step - accuracy: 0.4147 - loss: 1.6245 - val_accuracy: 0.4482 - val_loss: 1.6626 - learning_rate: 3.0000e-04
# Epoch 3/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 57s 81ms/step - accuracy: 0.4580 - loss: 1.5083 - val_accuracy: 0.4782 - val_loss: 1.5833 - learning_rate: 3.0000e-04
# Epoch 4/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 57s 81ms/step - accuracy: 0.4915 - loss: 1.4233 - val_accuracy: 0.4522 - val_loss: 1.6806 - learning_rate: 3.0000e-04
# Epoch 5/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 57s 81ms/step - accuracy: 0.5109 - loss: 1.3683 - val_accuracy: 0.5308 - val_loss: 1.3786 - learning_rate: 3.0000e-04
# Epoch 6/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 57s 80ms/step - accuracy: 0.5308 - loss: 1.3122 - val_accuracy: 0.5214 - val_loss: 1.4661 - learning_rate: 3.0000e-04
# Epoch 7/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.5489 - loss: 1.2713 - val_accuracy: 0.5540 - val_loss: 1.3223 - learning_rate: 3.0000e-04
# Epoch 8/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.5651 - loss: 1.2327 - val_accuracy: 0.5762 - val_loss: 1.3143 - learning_rate: 3.0000e-04
# Epoch 9/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 55s 79ms/step - accuracy: 0.5770 - loss: 1.2033 - val_accuracy: 0.4832 - val_loss: 1.5532 - learning_rate: 3.0000e-04
# Epoch 10/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 55s 79ms/step - accuracy: 0.5863 - loss: 1.1769 - val_accuracy: 0.6274 - val_loss: 1.0479 - learning_rate: 3.0000e-04
# Epoch 11/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 57s 80ms/step - accuracy: 0.5964 - loss: 1.1528 - val_accuracy: 0.6228 - val_loss: 1.1180 - learning_rate: 3.0000e-04
# Epoch 12/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.6053 - loss: 1.1226 - val_accuracy: 0.6352 - val_loss: 1.0627 - learning_rate: 3.0000e-04
# Epoch 13/50
# 703/704 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6099 - loss: 1.1097
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6134 - loss: 1.1056 - val_accuracy: 0.5978 - val_loss: 1.2080 - learning_rate: 3.0000e-04
# Epoch 14/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.6313 - loss: 1.0598 - val_accuracy: 0.6584 - val_loss: 0.9896 - learning_rate: 1.5000e-04
# Epoch 15/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6363 - loss: 1.0392 - val_accuracy: 0.6256 - val_loss: 1.0858 - learning_rate: 1.5000e-04
# Epoch 16/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.6423 - loss: 1.0237 - val_accuracy: 0.6428 - val_loss: 1.0338 - learning_rate: 1.5000e-04
# Epoch 17/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.6428 - loss: 1.0180 - val_accuracy: 0.6638 - val_loss: 0.9670 - learning_rate: 1.5000e-04
# Epoch 18/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 57s 81ms/step - accuracy: 0.6516 - loss: 1.0019 - val_accuracy: 0.6346 - val_loss: 1.0613 - learning_rate: 1.5000e-04
# Epoch 19/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6522 - loss: 0.9968 - val_accuracy: 0.7008 - val_loss: 0.8272 - learning_rate: 1.5000e-04
# Epoch 20/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.6577 - loss: 0.9859 - val_accuracy: 0.6614 - val_loss: 0.9851 - learning_rate: 1.5000e-04
# Epoch 21/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.6609 - loss: 0.9743 - val_accuracy: 0.6314 - val_loss: 1.0655 - learning_rate: 1.5000e-04
# Epoch 22/50
# 703/704 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6651 - loss: 0.9634
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6644 - loss: 0.9642 - val_accuracy: 0.6690 - val_loss: 0.9777 - learning_rate: 1.5000e-04
# Epoch 23/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6717 - loss: 0.9457 - val_accuracy: 0.6768 - val_loss: 0.9327 - learning_rate: 7.5000e-05
# Epoch 24/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6759 - loss: 0.9350 - val_accuracy: 0.7060 - val_loss: 0.8299 - learning_rate: 7.5000e-05
# Epoch 25/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 55s 78ms/step - accuracy: 0.6754 - loss: 0.9346 - val_accuracy: 0.7050 - val_loss: 0.8259 - learning_rate: 7.5000e-05
# Epoch 26/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6801 - loss: 0.9276 - val_accuracy: 0.7196 - val_loss: 0.7869 - learning_rate: 7.5000e-05
# Epoch 27/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.6801 - loss: 0.9216 - val_accuracy: 0.7058 - val_loss: 0.8193 - learning_rate: 7.5000e-05
# Epoch 28/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6810 - loss: 0.9153 - val_accuracy: 0.6976 - val_loss: 0.8765 - learning_rate: 7.5000e-05
# Epoch 29/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6839 - loss: 0.9124 - val_accuracy: 0.7210 - val_loss: 0.7810 - learning_rate: 7.5000e-05
# Epoch 30/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.6822 - loss: 0.9152 - val_accuracy: 0.7248 - val_loss: 0.7790 - learning_rate: 7.5000e-05
# Epoch 31/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 55s 79ms/step - accuracy: 0.6860 - loss: 0.9033 - val_accuracy: 0.7104 - val_loss: 0.8302 - learning_rate: 7.5000e-05
# Epoch 32/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 80ms/step - accuracy: 0.6883 - loss: 0.9024 - val_accuracy: 0.6980 - val_loss: 0.8580 - learning_rate: 7.5000e-05
# Epoch 33/50
# 703/704 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6919 - loss: 0.8952
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6895 - loss: 0.8984 - val_accuracy: 0.7238 - val_loss: 0.8072 - learning_rate: 7.5000e-05
# Epoch 34/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6908 - loss: 0.8932 - val_accuracy: 0.7024 - val_loss: 0.8591 - learning_rate: 3.7500e-05
# Epoch 35/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 56s 79ms/step - accuracy: 0.6920 - loss: 0.8845 - val_accuracy: 0.7092 - val_loss: 0.8288 - learning_rate: 3.7500e-05
# Epoch 36/50
# 703/704 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6924 - loss: 0.8834
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.8750000890577212e-05.
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 55s 79ms/step - accuracy: 0.6949 - loss: 0.8837 - val_accuracy: 0.7220 - val_loss: 0.8024 - learning_rate: 3.7500e-05
# Epoch 37/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 55s 79ms/step - accuracy: 0.6966 - loss: 0.8722 - val_accuracy: 0.7184 - val_loss: 0.7916 - learning_rate: 1.8750e-05
# Epoch 38/50
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 55s 79ms/step - accuracy: 0.6955 - loss: 0.8741 - val_accuracy: 0.7170 - val_loss: 0.8002 - learning_rate: 1.8750e-05
# >>> TRAINING STARTING <<<

# %%
# Evaluate Testing Data

test_loss, test_accuracy = evaluate_model(model, x_test, y_test)
print(f"Test accuracy: {test_accuracy:.2%}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# Test accuracy: 72.45%
# Test Loss: 0.8050

# %%
# Metrics

y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = y_test

cm = confusion_matrix(y_true, y_pred, config.NUM_CLASSES)
cm_norm = cm / cm.sum(axis=1, keepdims=True)
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']


# notmalized confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm_norm,annot=True, fmt=".2%", cmap="Blues", 
            xticklabels=class_names, yticklabels=class_names)

plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Normalized Confusion Matrix")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step

# %%
# Plot Training Data
val_loss = history.history['val_loss']
loss = history.history['loss']

# Cleaner and more explicit than hardcoding a range - becomes useful when EarlyStopping comes into play (we pass 'loss' but it could be any history.history.keys() as they all have same length)
epoch_axis = range(1, len(history.history["loss"]) + 1)

plt.figure()
plt.plot(epoch_axis, loss, label="Training loss")
plt.plot(epoch_axis, val_loss, label="Validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()

# storing accuracy metrics
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

plt.figure()
plt.plot(epoch_axis, accuracy, label="Training accuracy")
plt.plot(epoch_axis, val_accuracy, label="Validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training vs Validation Accuracy")
plt.show()


# print last epoch training data results to snapshot the current model performance [tracked in Excel file]
print(f'Training Loss: {loss[-1]:4f}')
print(f'Validation Loss: {val_loss[-1]:4f}')
print(f'Training Accuracy: {accuracy[-1]:.2%}')
print(f'Validation Accuracy: {val_accuracy[-1]:.2%}')
print('\n')

# Print out the best epoch where val_loss was at a minimum
best_epoch = np.argmin(val_loss)

# Results below are diagnostics only (not used for Excel reporting)
print(f"Best Epoch: {best_epoch + 1}")
print(f"Best Training Loss: {loss[best_epoch]:.4f}")
print(f"Best Validation Loss: {val_loss[best_epoch]:.4f}")
print(f"Best Training Accuracy: {accuracy[best_epoch]:.2%}")
print(f"Best Validation Accuracy: {val_accuracy[best_epoch]:.2%}")
# Out:
# Training Loss: 0.874079
# Validation Loss: 0.800158
# Training Accuracy: 69.55%
# Validation Accuracy: 71.70%
#
#
# Best Epoch: 30
# Best Training Loss: 0.9152
# Best Validation Loss: 0.7790
# Best Training Accuracy: 68.22%
# Best Validation Accuracy: 72.48%
